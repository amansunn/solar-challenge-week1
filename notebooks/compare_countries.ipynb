# %% [markdown]
# # Cross-Country Solar Potential Comparison
#
# This notebook synthesizes cleaned solar datasets from Benin, Sierra Leone, and Togo to compare solar potential and highlight key differences across countries.

# %%
# 1. Setup: Import libraries and initialize CountryComparator
import sys
sys.path.append('../')  

from src.country_comparator import CountryComparator

# Initialize the comparator with paths to cleaned data
comparator = CountryComparator(
    './notebooks/data/benin_clean.csv',
    './notebooks/data/sierraleone_clean.csv',
    './notebooks/data/togo_clean.csv'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 from src.country_comparator import CountryComparator
#       7 # Initialize the comparator with paths to cleaned data
# ----> 8 comparator = CountryComparator(
#       9     '../data/benin_clean.csv',
#      10     '../data/sierraleone_clean.csv',
#      11     '../data/togo_clean.csv'
#      12 )
#
# File c:\Users\lukam\Desktop\solar-challenge-week1\notebooks\..\src\country_comparator.py:15, in CountryComparator.__init__(self, benin_path, sierraleone_path, togo_path)
#      11 def __init__(self, benin_path, sierraleone_path, togo_path):
#      12     """
#      13     Load cleaned datasets and combine them for analysis.
#      14     """
# ---> 15     self.df_benin = pd.read_csv(benin_path, parse_dates=['Timestamp'])
# ...

# %% [markdown]
# ## Metric Comparison: Boxplots of GHI, DNI, DHI by Country

# %%
# Boxplots for GHI, DNI, DHI
comparator.plot_boxplots()
# Out:
# d:\Personal Projects\TENx\Code\solar-challenge-week1\notebooks\..\src\country_comparator.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Country', y=metric, data=self.df_all, palette='Set2')
# d:\Personal Projects\TENx\Code\solar-challenge-week1\notebooks\..\src\country_comparator.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Country', y=metric, data=self.df_all, palette='Set2')
# d:\Personal Projects\TENx\Code\solar-challenge-week1\notebooks\..\src\country_comparator.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## Summary Table: Mean, Median, and Standard Deviation of GHI, DNI, DHI

# %%
# Summary table for each metric by country
summary = comparator.summary_table()
display(summary)
# Out:
#                      GHI                            DNI                     \
#                     mean median         std        mean median         std
# Country
# Benin         196.440576    0.0  291.236243  104.527217   -0.1  201.696328
# Sierra Leone  196.440576    0.0  291.236243  104.527217   -0.1  201.696328
# Togo          229.831878    2.0  321.643788  149.368966    0.0  248.554496
#
#                      DHI
#                     mean median         std
# Country
# Benin         110.107836   -0.4  154.171728
# Sierra Leone  110.107836   -0.4  154.171728
# Togo          112.404125    1.8  151.296253

# %% [markdown]
# ## Statistical Testing: One-way ANOVA and Kruskal–Wallis Test for GHI

# %%
# Statistical tests for GHI
pvals = comparator.statistical_tests()
print(f"One-way ANOVA p-value: {pvals['anova_p']:.4f}")
print(f"Kruskal–Wallis p-value: {pvals['kruskal_p']:.4f}")
# Out:
# One-way ANOVA p-value: 0.0000
# Kruskal–Wallis p-value: 0.0000

# %% [markdown]
# ## Key Observations
# - (1) [Fill in after reviewing results] One country may show the highest median GHI but also the greatest variability.
# - (2) [Fill in after reviewing results] Statistical tests indicate whether differences in GHI are significant across countries (see p-values above).
# - (3) [Fill in after reviewing results] Actionable insight, e.g., which country is best suited for solar investment based on both average and variability.

# %% [markdown]
# ## Visual Summary: Bar Chart Ranking Countries by Average GHI

# %%
# Bar chart of average GHI by country
comparator.plot_avg_ghi_bar()
# Out:
# d:\Personal Projects\TENx\Code\solar-challenge-week1\notebooks\..\src\country_comparator.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_ghi.index, y=avg_ghi.values, palette='viridis')
